# %% [markdown]
# ##Q.1
#
# GET The GET method is used to retrieve or request data from a specified resource. When a client sends a GET request to a server, it expects to recieve data in response.
#
# POST The POST method is used to submit data to be processed to a specified resource. When a client sends a POST request to a server, it includes data in the request body.

# %% [markdown]
# ##Q.2
#
# In flask the request object is used to access the data that is sent by the client as part of an HTTP request. It allows you to retrieve information such as form data, URL parameters , headers , cookies etc.

# %% [markdown]
# ##Q.3
#
# redirect() function is used to redirect the users browser to a different URL. It is useful in route to redirect

# %% [markdown]
# ##Q.4
#
# In flask , templates are files that contain HTML structure of web pages or parts of web pages.
#
# The render_template() function in Flask is used to render and return a template as a response to an HTTP request.

# %% [markdown]
# # Q.5 Screenshot
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
# Code

from flask import Flask, render_template , request , jsonify , url_for

app = Flask(__name__)

@app.route('/',methods = ['GET','POST'])
def home_page():
    return "Welcome" 

@app.route('/postman_data', methods = ['POST'])
def math_operation1():
    if(request.method == 'POST'):
        ops = request.json['operation']
        num1 = int(request.json['num1'])
        num2 = int(request.json['num2'])
        if(ops == 'add'):
            r = num1 + num2
            result = 'the sum of '+str(num1) + ' and ' +str(num2) + ' is ' + str(r)

        if(ops == 'subtract'):
            r = num1 - num2
            result = 'the subtract of '+str(num1) + ' and ' +str(num2) + ' is ' + str(r)

        if(ops == 'multiply'):
            r = num1 * num2
            result = 'the multiply of '+str(num1) + ' and ' +str(num2) + ' is ' + str(r)

        if(ops == 'divide'):
            r = num1 / num2
            result = 'the division of '+str(num1) + ' and ' +str(num2) + ' is ' + str(r)
        return jsonify(result)   

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.153.175:5000/ (Press CTRL+C to quit)
